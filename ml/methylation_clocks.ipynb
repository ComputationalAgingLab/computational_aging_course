# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# # Preprocess
#
# Here we preprocess data

# %% [markdown]
# # Process

# %% [markdown]
# # Naive model
